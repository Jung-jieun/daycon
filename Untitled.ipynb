# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv(r"C:\Users\82109\OneDrive\바탕 화면\train.csv")
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955 entries, 0 to 1954
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1955 non-null   int64
#  1   Age                       1861 non-null   float64
#  2   TypeofContact             1945 non-null   object
#  3   CityTier                  1955 non-null   int64
#  4   DurationOfPitch           1853 non-null   float64
#  5   Occupation                1955 non-null   object
#  6   Gender                    1955 non-null   object
#  7   NumberOfPersonVisiting    1955 non-null   int64
#  8   NumberOfFollowups         1942 non-null   float64
#  9   ProductPitched            1955 non-null   object
#  10  PreferredPropertyStar     1945 non-null   float64
#  11  MaritalStatus             1955 non-null   object
#  12  NumberOfTrips             1898 non-null   float64
# ...

# %%
test = pd.read_csv(r"C:\Users\82109\OneDrive\바탕 화면\test.csv")
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2933 entries, 0 to 2932
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        2933 non-null   int64
#  1   Age                       2801 non-null   float64
#  2   TypeofContact             2918 non-null   object
#  3   CityTier                  2933 non-null   int64
#  4   DurationOfPitch           2784 non-null   float64
#  5   Occupation                2933 non-null   object
#  6   Gender                    2933 non-null   object
#  7   NumberOfPersonVisiting    2933 non-null   int64
#  8   NumberOfFollowups         2901 non-null   float64
#  9   ProductPitched            2933 non-null   object
#  10  PreferredPropertyStar     2917 non-null   float64
#  11  MaritalStatus             2933 non-null   object
#  12  NumberOfTrips             2850 non-null   float64
# ...

# %%
sns.barplot(x='NumberOfTrips', y='ProdTaken', data=train)
plt.show()

# %%
sns.barplot(x='ProdTaken', y='NumberOfTrips', hue='Gender',data=train)
plt.show()

# %%
train['Gender'].value_counts()
# Out:
# Male       1207
# Female      692
# Fe Male      56
# Name: Gender, dtype: int64

# %%
train = train.replace('Fe Male', 'Female')
train['Gender'].value_counts()
# Out:
# Male      1207
# Female     748
# Name: Gender, dtype: int64

# %%
test['Gender'].value_counts()
# Out:
# Male       1709
# Female     1125
# Fe Male      99
# Name: Gender, dtype: int64

# %%
train[train['NumberOfTrips']==19]
# Out:
#       id   Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 987  988  30.0  Company Invited         1             10.0  Large Business
#
#     Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 987   Male                       2                3.0          Basic
#
#      PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 987                    3.0        Single           19.0         1
#
#      PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 987                       4       1                       1.0   Executive
#
#      MonthlyIncome  ProdTaken
# 987        17285.0          1

# %%
train[train['NumberOfTrips'].isna()]
# Out:
#         id   Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 93      94  42.0     Self Enquiry         2             17.0        Salaried
# 95      96  51.0  Company Invited         1              9.0  Small Business
# 118    119  43.0  Company Invited         1              9.0        Salaried
# 125    126  45.0     Self Enquiry         3             16.0        Salaried
# 200    201  51.0     Self Enquiry         1              7.0  Small Business
# 209    210  45.0     Self Enquiry         3             12.0  Small Business
# 231    232  53.0     Self Enquiry         1              7.0        Salaried
# 265    266  42.0  Company Invited         1             16.0  Small Business
# 289    290  47.0     Self Enquiry         3             10.0  Small Business
# 308    309  43.0     Self Enquiry         1              9.0  Small Business
# 311    312  40.0  Company Invited         1              7.0        Salaried
# ...

# %%
train.groupby(['Gender', 'ProdTaken']).mean()['NumberOfTrips']
# Out:
# Gender  ProdTaken
# Female  0            3.191597
#         1            3.058394
# Male    0            3.229686
#         1            3.621399
# Name: NumberOfTrips, dtype: float64

# %%
train[train['Gender']=='Female'].mean()['NumberOfTrips']
# Out:
# C:\Users\82109\AppData\Local\Temp/ipykernel_21808/3514332435.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train[train['Gender']=='Female'].mean()['NumberOfTrips']
# 3.1666666666666665
